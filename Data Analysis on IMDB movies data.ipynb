# %% [markdown]
# Data Analysis on IMDB movies data

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sanda\Desktop\IMDB-Movie-Data.csv")

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
genre=df.Genre
genre
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
df[['Genre']]
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
some_cols=df[['Title',	'Genre'	,'Description'	,'Director',	'Actors']]
some_cols
# Out:
#                        Title                     Genre  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.iloc[2]
# Out:
# Title                                                             Split
# Rank                                                                  3
# Genre                                                   Horror,Thriller
# Description           Three girls are kidnapped by a man with a diag...
# Director                                             M. Night Shyamalan
# Actors                James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                               2016
# Runtime (Minutes)                                                   117
# Rating                                                              7.3
# Votes                                                            157606
# Revenue (Millions)                                               138.12
# Metascore                                                          62.0
# Name: 2, dtype: object

# %%
df.iloc[6:10]
# Out:
#                 Title  Rank                       Genre  \
# 6          La La Land     7          Comedy,Drama,Music
# 7            Mindhorn     8                      Comedy
# 8  The Lost City of Z     9  Action,Adventure,Biography
# 9          Passengers    10     Adventure,Drama,Romance
#
#                                          Description         Director  \
# 6  A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 7  A has-been actor best known for playing the ti...       Sean Foley
# 8  A true-life drama, centering on British explor...       James Gray
# 9  A spacecraft traveling to a distant colony pla...    Morten Tyldum
#
#                                               Actors  Year  Runtime (Minutes)  \
# 6  Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016                128
# 7  Essie Davis, Andrea Riseborough, Julian Barrat...  2016                 89
# 8  Charlie Hunnam, Robert Pattinson, Sienna Mille...  2016                141
# ...

# %%
df.set_index(['Title'], inplace=True)
df.loc[['Suicide Squad']]
# Out:
#                Rank                     Genre  \
# Title
# Suicide Squad     5  Action,Adventure,Fantasy
#
#                                                      Description    Director  \
# Title
# Suicide Squad  A secret government agency recruits some of th...  David Ayer
#
#                                                           Actors  Year  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
#
#                Runtime (Minutes)  Rating   Votes  Revenue (Millions)  \
# Title
# Suicide Squad                123     6.2  393727              325.02
#
#                Metascore
# Title
# Suicide Squad       40.0

# %%
df.reset_index(inplace=True)

# %%
df[['Director']]
# Out:
#                  Director
# 0              James Gunn
# 1            Ridley Scott
# 2      M. Night Shyamalan
# 3    Christophe Lourdelet
# 4              David Ayer
# ..                    ...
# 995             Billy Ray
# 996              Eli Roth
# 997            Jon M. Chu
# 998        Scot Armstrong
# 999      Barry Sonnenfeld
#
# [1000 rows x 1 columns]

# %%
df['Director'].nunique()
# Out:
# 644

# %%
df['Director'].value_counts()
# Out:
# Director
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
#                      ..
# Lee Toland Krieger    1
# Gillies MacKinnon     1
# Peter Atencio         1
# James Mangold         1
# Scot Armstrong        1
# Name: count, Length: 644, dtype: int64

# %%
df.groupby(['Director'])[['Revenue (Millions)']].sum()
# Out:
#                      Revenue (Millions)
# Director
# Aamir Khan                         1.20
# Abdellatif Kechiche                2.20
# Adam Leon                          0.00
# Adam McKay                       438.14
# Adam Shankman                    157.33
# ...                                 ...
# Xavier Dolan                       3.49
# Yimou Zhang                       45.13
# Yorgos Lanthimos                   8.81
# Zack Snyder                      975.74
# Zackary Adler                      6.53
#
# [644 rows x 1 columns]

# %%
df.groupby('Director')[['Rating']].mean().sort_values(by='Rating', ascending=True)
# Out:
#                    Rating
# Director
# Jason Friedberg      1.90
# James Wong           2.70
# Shawn Burkett        2.70
# Jonathan Holbrook    3.20
# Femi Oyeniran        3.50
# ...                   ...
# Aamir Khan           8.50
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Christopher Nolan    8.68
# Nitesh Tiwari        8.80
#
# [644 rows x 1 columns]

# %%
df[df['Rating'] == df['Rating'].min()][['Title','Actors','Director','Year','Rating']]
# Out:
#               Title                                             Actors  \
# 829  Disaster Movie  Carmen Electra, Vanessa Lachey,Nicole Parker, ...
#
#             Director  Year  Rating
# 829  Jason Friedberg  2008     1.9

# %%
movies=df[((df['Year'] >= 2010) &( df['Year'] <= 2016)) & (df['Rating']<6.0) ]

# %%
movies
# Out:
#                                 Title  Rank                     Genre  \
# 24       Independence Day: Resurgence    25   Action,Adventure,Sci-Fi
# 27                         Dead Awake    28           Horror,Thriller
# 29                   Assassin's Creed    30    Action,Adventure,Drama
# 34   Resident Evil: The Final Chapter    35      Action,Horror,Sci-Fi
# 42            Don't Fuck in the Woods    43                    Horror
# ..                                ...   ...                       ...
# 985                     Your Highness   986  Adventure,Comedy,Fantasy
# 986               Final Destination 5   987           Horror,Thriller
# 993          Resident Evil: Afterlife   994   Action,Adventure,Horror
# 998                      Search Party   999          Adventure,Comedy
# 999                        Nine Lives  1000     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# ...

# %%
rating_avg = df.groupby(['Director'])[['Rating']].mean().head()

# %%
rating_avg
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
rating_avg.sort_values(by=['Rating'],ascending=True )
# Out:
#                      Rating
# Director
# Adam Shankman           6.3
# Adam Leon               6.5
# Adam McKay              7.0
# Abdellatif Kechiche     7.8
# Aamir Khan              8.5

# %%
df.isnull().sum()
# Out:
# Title                   0
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.drop(['Metascore'], inplace=True, axis=1)

# %%
df.isnull().sum()
# Out:
# Title                   0
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# dtype: int64

# %%
mean_rev=round(df['Revenue (Millions)'].mean(),2)
mean_rev
# Out:
# 82.96

# %%
df['Revenue (Millions)'].fillna(mean_rev,inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                 0
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# dtype: int64

# %%
def rating_group(rating):
    if rating >= 7.5:
        return 'Good'
    elif rating >= 6.0:
        return 'Average'
    else:
        return 'Bad'

# %%
df['rating_category']=df['Rating'].apply(rating_group)

# %%
df[['Title','Rating','rating_category']]
# Out:
#                        Title  Rating rating_category
# 0    Guardians of the Galaxy     8.1            Good
# 1                 Prometheus     7.0         Average
# 2                      Split     7.3         Average
# 3                       Sing     7.2         Average
# 4              Suicide Squad     6.2         Average
# ..                       ...     ...             ...
# 995     Secret in Their Eyes     6.2         Average
# 996          Hostel: Part II     5.5             Bad
# 997   Step Up 2: The Streets     6.2         Average
# 998             Search Party     5.6             Bad
# 999               Nine Lives     5.3             Bad
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#                        Title  Rank                     Genre  \
# 0    Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# 1                 Prometheus     2  Adventure,Mystery,Sci-Fi
# 2                      Split     3           Horror,Thriller
# 3                       Sing     4   Animation,Comedy,Family
# 4              Suicide Squad     5  Action,Adventure,Fantasy
# ..                       ...   ...                       ...
# 995     Secret in Their Eyes   996       Crime,Drama,Mystery
# 996          Hostel: Part II   997                    Horror
# 997   Step Up 2: The Streets   998       Drama,Music,Romance
# 998             Search Party   999          Adventure,Comedy
# 999               Nine Lives  1000     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df[df['Rating'] > 8]
# Out:
#                                             Title  Rank  \
# 0                         Guardians of the Galaxy     1
# 6                                      La La Land     7
# 16                                  Hacksaw Ridge    17
# 18                                           Lion    19
# 26                        Bahubali: The Beginning    27
# 36                                   Interstellar    37
# 50     Star Wars: Episode VII - The Force Awakens    51
# 54                                The Dark Knight    55
# 64                                   The Prestige    65
# 67                             Mad Max: Fury Road    68
# 74                                       Zootopia    75
# 76                                   The Avengers    77
# 77                           Inglourious Basterds    78
# 80                                      Inception    81
# 82                        The Wolf of Wall Street    83
# 83                                      Gone Girl    84
# ...

# %%
filter=df['Rating'] > 7
df.where(filter).dropna()
# Out:
#                        Title   Rank                       Genre  \
# 0    Guardians of the Galaxy    1.0     Action,Adventure,Sci-Fi
# 2                      Split    3.0             Horror,Thriller
# 3                       Sing    4.0     Animation,Comedy,Family
# 6                 La La Land    7.0          Comedy,Drama,Music
# 8         The Lost City of Z    9.0  Action,Adventure,Biography
# ..                       ...    ...                         ...
# 979       The Skin I Live In  980.0              Drama,Thriller
# 982      Across the Universe  983.0       Drama,Fantasy,Musical
# 988                  Martyrs  989.0                      Horror
# 989                    Selma  990.0     Biography,Drama,History
# 991         Taare Zameen Par  992.0          Drama,Family,Music
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'rating_category'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.nlargest(n=1, columns=['Rating'])
# Out:
#               Title  Rank               Genre  \
# 54  The Dark Knight    55  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#     Runtime (Minutes)  Rating    Votes  Revenue (Millions) rating_category
# 54                152     9.0  1791916              533.32            Good

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df['Rating'].unique()
# Out:
# array([8.1, 7. , 7.3, 7.2, 6.2, 6.1, 8.3, 6.4, 7.1, 7.5, 7.8, 7.9, 7.7,
#        6.6, 8.2, 6.7, 8. , 6.5, 5.3, 6.8, 4.7, 5.9, 6.3, 5.6, 8.6, 7.6,
#        6.9, 2.7, 3.7, 5.8, 9. , 7.4, 4.1, 8.5, 8.8, 5.4, 6. , 5.7, 8.4,
#        5.2, 5.5, 4.8, 3.9, 4.9, 5.1, 5. , 4.3, 4.6, 4.2, 4. , 3.2, 4.5,
#        1.9, 3.5, 4.4])

# %%
df['Rating'].nunique()
# Out:
# 55

# %%
df['Rating'].idxmax()
# Out:
# 54

# %%
df.head()
# Out:
#                      Title  Rank                     Genre  \
# 0  Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# 1               Prometheus     2  Adventure,Mystery,Sci-Fi
# 2                    Split     3           Horror,Thriller
# 3                     Sing     4   Animation,Comedy,Family
# 4            Suicide Squad     5  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.pivot_table(index='Director',columns='Year', values='Revenue (Millions)',aggfunc='sum')
# Out:
# Year                   2006    2007    2008    2009    2010   2011   2012  \
# Director
# Aamir Khan              NaN    1.20     NaN     NaN     NaN    NaN    NaN
# Abdellatif Kechiche     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# Adam Leon               NaN     NaN     NaN     NaN     NaN    NaN    NaN
# Adam McKay           148.21     NaN  100.47     NaN  119.22    NaN    NaN
# Adam Shankman           NaN  118.82     NaN     NaN     NaN    NaN  38.51
# ...                     ...     ...     ...     ...     ...    ...    ...
# Xavier Dolan            NaN     NaN     NaN     NaN     NaN    NaN    NaN
# Yimou Zhang             NaN     NaN     NaN     NaN     NaN    NaN    NaN
# Yorgos Lanthimos        NaN     NaN     NaN    0.11     NaN    NaN    NaN
# Zack Snyder          210.59     NaN     NaN  107.50     NaN  36.38    NaN
# Zackary Adler           NaN     NaN     NaN     NaN     NaN    NaN    NaN
#
# Year                   2013  2014   2015    2016
# Director
# ...
